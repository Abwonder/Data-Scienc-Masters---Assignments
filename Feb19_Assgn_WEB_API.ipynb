# %% [markdown]
# ## Assignment
# ### Flask Introduction, Application, Open Link Flask, App Routing Flask Url Building Flask

# %% [markdown]
# ### Question 1
#
# Q1. What is Flask Framework? What are the advantages of Flask Framework?
#
# Flash Framework is a web framework that provides libraries to build lightweight web applications in python.
#
# Below listed are the advantages fo Flask Framework
#
#
# __Advantages of Flask__
# 1.  Higher compatibility with latest technologies
# 2.  Technical experimentation
# 3.  Easier to use for simple cases
# 4.  Codebase size is relatively smaller
# 5.  High scalability for simple applications,
# 6.  Easy to build a quick prototype
# 7.  Routing URL is easy
# 8.  Easy to develop and maintain applications
# 9.  Database integration is easy
# 10. Small core and easily extensible
# 11. Minimal yet powerful platform
# 12. Lots of resources available online especially on GitHub

# %% [markdown]
# ### Question 2
# Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in
# Jupyter Notebook.

# %%
## creating flash application to display "Hello World!"
from flask import Flask

app = Flask(__name__)

@app.route('/')
def hello_world():
    return "Hello World!!"

if __name__=="__main__":
    app.run(host="0.0.0.0")

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Question 3
#
# Q3. What is App routing in Flask? Why do we use app routes?
#
# App Routing meaning mapping the URLs to a specific function that will handle the logic for that URL.
#
# app routes is used to bind a function to an URL path which is done using the app.route decorator.

# %% [markdown]
# ### Question 4
#
# Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
# route to show the following details:
# Company Name: ABC Corporation
# Location: India
# Contact Detail: 999-999-9999
# Attach the screenshot of the output in Jupyter Notebook.

# %%
from flask import Flask

app = Flask(__name__)

@app.route('/')
def company_details():
    return '''
    Company Name: ABC Corporation
    Location: India
    Contact Detail: 999-999-9999
    '''

@app.route('/welcome')
def welcome_message():
    return "Welcome to ABC Corporation"

if __name__=="__main__":
    app.run(host="0.0.0.0")

# %% [markdown]
# ### default ("/")
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### url path ("/welcome")
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Question 5
#
# Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function.
#
#
# url_for in Flask is used for creating a URL to prevent the overhead of having to change URLs throughout an application (including in templates). Without url_for, if there is a change in the root URL of your app then you have to change it in every page where the link is present

# %%
## The coding url for family as example

from flask import Flask   ### library flask imported

app = Flask(__name__)   ## building object of Flask

## firstly build individual function mapped to url
@app.route("/father")  
def father():
    return "Father's name is Olushola David"

@app.route("/mother")
def mother():
    return "Mothers's name is Felicia Asabi"

@app.route("/son")
def son():
    return "I am the son, my name is Abwonder"

## build the condition for using url_for
@app.route("/family/<name>") ## <name> denotes the sub for the condition
def family():  ## function for the condition for determination!!!!
    if name == "father":
        return redirect(url_for("father"))
    if name == "mother":
        return redirect(url_for("mother"))
    if name == "son":
        return redirect(url_for("son"))
    
if __name__=="__main__":
    app.run(host="0.0.0.0")

# %% [markdown]
# ### first functional url
#
# ![image.png](attachment:image.png)
#
# ### second functional url
# ![image-2.png](attachment:image-2.png)
# ### third functional url
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### The End ######
