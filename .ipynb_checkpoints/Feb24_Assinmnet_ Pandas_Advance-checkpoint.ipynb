# %% [markdown]
# ###### Pandas Advance - 1

# %% [markdown]
# Q1. List any five functions of the pandas library with execution.
#
# below listed are the function
#
# 1. read_csv() -To read in data for data analysis using pandas
# 2. head() - Highlight the first 5 rows of the dataframe and can be set
# 3. tail() - reverse form of head and can also be set as the name indicates
# 4. describe() - provides summary statistics of numerical columns in a DataFrame
# 5. dtype() - output the data type of each column

# %%
### would list and demonstrate 5 pandas library functions with execution

import pandas as pd
## Load the dataset
## read()
example = pd.read_csv("services.csv")

# %%
##head()
example.head()
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
# 3   4            4         NaN               NaN            NaN
# 4   5            5         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
# 3                              Apply by phone.
# 4                       Phone for information.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
# 3  Parents, children, families with problems of c...
# ...

# %%
###tail
example.tail()
# Out:
#     id  location_id  program_id         accepted_payments  \
# 18  19           19         NaN                       NaN
# 19  20           20         NaN                       NaN
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                             application_process  \
# 18                    NaN  Call for screening appointment (650-347-3648).
# 19                    NaN                                        Walk in.
# 20                    NaN                 By phone during business hours.
# 21  Fotos para pasaportes               Walk in or apply by phone or mail
# 22                    NaN               Walk in or apply by phone or mail
#
#                                              audience  \
# 18                                                NaN
# 19                                                NaN
# ...

# %%
### describe()
example.describe()
# Out:
#              id  location_id  program_id
# count  23.00000    23.000000         0.0
# mean   12.00000    11.956522         NaN
# std     6.78233     6.711444         NaN
# min     1.00000     1.000000         NaN
# 25%     6.50000     6.500000         NaN
# 50%    12.00000    12.000000         NaN
# 75%    17.50000    17.500000         NaN
# max    23.00000    22.000000         NaN

# %%
## dtype()
example.dtypes
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %% [markdown]
# ### Question 2
# Q2. Given a Pandas DataFrame df with columns 'A', 'B', and 'C', write a Python function to re-index the
# DataFrame with a new index that starts from 1 and increments by 2 for each row.

# %%
## list comprehension to build the new index list
new_index = [x for x in range(1, len(df),2)]

### Then apply 
mp = df.reindex(new_index)
mp

# %%
### using dataframe in question 1 for demonstrations
## list comprehension to build the new index list
new_index = [x for x in range(1, len(df),2)]

### Then apply 
mp = example.reindex(new_index)
mp ### The index starts from 1 and progress!!!!
# Out:
#     id  location_id  program_id         accepted_payments  \
# 1    2            2         NaN                       NaN
# 3    4            4         NaN                       NaN
# 5    6            6         NaN                       NaN
# 7    8            8         NaN                       NaN
# 9   10           10         NaN                       NaN
# 11  12           12         NaN                       NaN
# 13  14           14         NaN                       NaN
# 15  16           16         NaN                       NaN
# 17  18           18         NaN                       NaN
# 19  20           20         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
#
#            alternate_name                                application_process  \
# 1                     NaN                 Apply by phone for an appointment.
# 3                     NaN                                    Apply by phone.
# ...

# %% [markdown]
# ### Question 3
# Q3. You have a Pandas DataFrame df with a column named 'Values'. Write a Python function that
# iterates over the DataFrame and calculates the sum of the first three values in the 'Values' column. The
# function should print the sum to the console.
# The
# function should print the sum to the console.
# For example, if the 'Values' column of df contains the values [10, 20, 30, 40, 50], your function should
# calculate and print the sum of the first three values, which is 60.

# %%
### Break down, this will involve picking out the column as series
df.["values"]

## then slice the range needed out
df.["values"][:5]

### then use a for loop to iterate over it and sum it

#### define variable
sum_first5 = 0

for value in df["values"][:5]:
    sum_first5 += value
print(sum_first5)

# %%
### using the example suggested 
# The
# function should print the sum to the console.
# For example, if the 'Values' column of df contains the values [10, 20, 30, 40, 50], your function should
# calculate and print the sum of the first three values, which is 60.

import pandas as pd

df = pd.DataFrame({"values":[10, 20, 30, 40, 50]})

sum_first5 = 0

for value in df["values"][:3]:
    sum_first5 += value
print(sum_first5)
# Out:
# 60

# %% [markdown]
# ### Question 4
# Q4. Given a Pandas DataFrame df with a column 'Text', write a Python function to create a new column
# 'Word_Count' that contains the number of words in each row of the 'Text' column.

# %%
## Answer to quetion 4
df["Worl_Count"] = df["Text"].str.split().apply(len)

# %%
### example for illustrations
import pandas as pd

# Create a sample DataFrame with a column of strings
df = pd.DataFrame({'text': ['this is me trying this out', 'another example sentence', 'one more sentence']})

# Split the strings in the 'text' column into lists of words
# df['words'] = df['text'].str.split()

# Count the number of words in each list using the len() function and assign the result to a new column
# df['word_count'] = df['words'].apply(len)

df['word_count'] = df['text'].str.split().apply(len)

# Print the resulting DataFrame
print(df)
# Out:
#                          text  word_count
# 0  this is me trying this out           6
# 1    another example sentence           3
# 2           one more sentence           3

# %% [markdown]
# ### Question 5
# Q5. How are DataFrame.size() and DataFrame.shape() different?
#
# DataFrame.size() and DataFrame.shape() different in the information they output when used, although both of them are Pandas DataFrame attributes: DataFrame.size() returns the total number of elements in the DataFrame which is the multiplication of the rows and columns i.e 2 by 3 (6 )while DataFrame.shape returns a tuple that contains the row and column numbers e.g  (2,3).

# %%
## An example of the above
import pandas as pd

# Create a sample DataFrame
df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6], 'C': [7, 8, 9], 'D': [10, 11, 12]})

# Get the size and shape of the DataFrame
print('DataFrame size:', df.size)
print('DataFrame shape:', df.shape)
# Out:
# DataFrame size: 12
# DataFrame shape: (3, 4)

# %% [markdown]
# ### Question 6
# Q6. Which function of pandas do we use to read an excel file?
#
# import pandas as pd
#
# pd.read_excel() -- is used for reading excel files in Pandas

# %% [markdown]
# ### Question 7
# Q7. You have a Pandas DataFrame df that contains a column named 'Email' that contains email
# addresses in the format 'username@domain.com'. Write a Python function that creates a new column
# 'Username' in df that contains only the username part of each email address.
# The username is the part of the email address that appears before the '@' symbol. For example, if the
# email address is 'john.doe@example.com', the 'Username' column should contain 'john.doe'. Your
# function should extract the username from each email address and store it in the new 'Username'
# column.

# %%
df["Username"] = df["Email"].apply(lambda x: x.split("@")[0])

# %%
#Examplet to back up the answer!!!
df_email = pd.DataFrame({"Email Addresses":['john.doe@example.com', "elijah@gmail.com", "angelmichael@yahoo.com"]})

df_email
# Out:
#           Email Addresses
# 0    john.doe@example.com
# 1        elijah@gmail.com
# 2  angelmichael@yahoo.com

# %%
##Note: str needs to come before the split for strings values
df_email["Username"] = df_email["Email Addresses"].apply(lambda x: x.split("@")[0])

df_email
# Out:
#           Email Addresses      Username
# 0    john.doe@example.com      john.doe
# 1        elijah@gmail.com        elijah
# 2  angelmichael@yahoo.com  angelmichael

# %% [markdown]
# ### Question 8
# Q8. You have a Pandas DataFrame df with columns 'A', 'B', and 'C'. Write a Python function that selects
# all rows where the value in column 'A' is greater than 5 and the value in column 'B' is less than 10. The
# function should return a new DataFrame that contains only the selected rows.
# For example, if df contains the following values:
# A B C
# 0 3 5 1
# 1 8 2 7
# 2 6 9 4
# 3 2 3 5
# 4 9 1 2
#
# Assignment
#
# Data Science Masters
#
# Your function should select the following rows: A B C
# 1 8 2 7
# 4 9 1 2
# The function should return a new DataFrame that contains only the selected rows.

# %%
## answer to the question above
newdf1[ (newdf1["A"] > 5) & (newdf1["B"] < 10) ]

# %%
### Replicating the example floated in the question to back up my answer
import pandas as pd

newdf1 = pd.DataFrame({"A":[3,8,6,2,9], "B":[5,2,9,3,1], "C":[1,7,4,5,2]})
newdf1
# Out:
#    A  B  C
# 0  3  5  1
# 1  8  2  7
# 2  6  9  4
# 3  2  3  5
# 4  9  1  2

# %%
## The result for the conditions
newdf1[ (newdf1["A"] > 5) & (newdf1["B"] < 10) ]
# Out:
#    A  B  C
# 1  8  2  7
# 2  6  9  4
# 4  9  1  2

# %% [markdown]
# ### Question 9
# Q9. Given a Pandas DataFrame df with a column 'Values', write a Python function to calculate the mean,
# median, and standard deviation of the values in the 'Values' column.

# %%
## function to calculate statistics (mean, median and standard deviation)
import pandas as pd
## data
df
##function
def calculate_statistics(df):
    mean = df["values"].mean()
    median = df["values"].median()
    std_dev = df["values"].std()
    return mean, median, std_dev
mean, median, std_dev = calculate_statistics(df)
print('Mean:', mean)
print('Median:', median)
print('Standard deviation:', std_dev)

# %%
### Example to back up the answer
import pandas as pd

newdf1 = pd.DataFrame({"A":[3,8,6,2,9], "B":[5,2,9,3,1], "C":[1,7,4,5,2]})
# newdf1

def calculate_statistics(newdf1):
    mean = newdf1["A"].mean()
    median = newdf1["A"].median()
    std_dev = newdf1["A"].std()
    return mean, median, std_dev
mean, median, std_dev = calculate_statistics(newdf1)
print('Mean:', mean)
print('Median:', median)
print('Standard deviation:', std_dev)
# Out:
# Mean: 5.6
# Median: 6.0
# Standard deviation: 3.0495901363953815

# %% [markdown]
# ### Question 10
# Q10. Given a Pandas DataFrame df with a column 'Sales' and a column 'Date', write a Python function to
# create a new column 'MovingAverage' that contains the moving average of the sales for the past 7 days
# for each row in the DataFrame. The moving average should be calculated using a window of size 7 and
# should include the current day.

# %%
import pandas as pd
#datasetframe

def moving_avg_add(df):
### arrange the dates in orderly manner
    df = df.sort_values('Date')

    # Calculate the rolling average with a window of 7 days, including the current day
    rolling_avg = df['Sales'].rolling(window=7, min_periods=1).mean()

    # Add the rolling average as a new column in the DataFrame
    df['MovingAverage'] = rolling_avg
    
    return df

## adding the moving average colunm to the DataFrame
df = moving_avg_add(df)

# %% [markdown]
# ### Question 11
# Q11 You have a Pandas DataFrame df with a column 'Date'. Write a Python function that creates a new
# column 'Weekday' in the DataFrame. The 'Weekday' column should contain the weekday name (e.g.
# Monday, Tuesday) corresponding to each date in the 'Date' column.
# For example, if df contains the following values:
# Date
# 0 2023-01-01
# 1 2023-01-02
# 2 2023-01-03
# 3 2023-01-04
# 4 2023-01-05
# Your function should create the following DataFrame:
#
# Date Weekday
# 0 2023-01-01 Sunday
# 1 2023-01-02 Monday
# 2 2023-01-03 Tuesday
# 3 2023-01-04 Wednesday
# 4 2023-01-05 Thursday
# The function should return the modified DataFrame.

# %%
## Will use this example to answer the question above
import pandas as pd
## creating the dataframe
df = pd.DataFrame({"Date":["2023-01-01", "2023-01-02", "2023-01-03", "2023-01-04", "2023-01-05"]})

## creating the function to add weekday column
def weekday_col_add(df):
    ## convert it to datetime format while picking it out as series
    df["Date"] = pd.to_datetime(df["Date"])
    ## creating new column in weekday format
    df["Weekday"] = df["Date"].dt.day_name()
    return df

df = weekday_col_add(df)
df
# Out:
#         Date    Weekday
# 0 2023-01-01     Sunday
# 1 2023-01-02     Monday
# 2 2023-01-03    Tuesday
# 3 2023-01-04  Wednesday
# 4 2023-01-05   Thursday

# %% [markdown]
# ### Question 12
# Q12. Given a Pandas DataFrame df with a column 'Date' that contains timestamps, write a Python
# function to select all rows where the date is between '2023-01-01' and '2023-01-31'

# %%
df[ (df["Date"] > '2023-01-01') & (df["Date"] > '2023-01-31') ]

# %% [markdown]
# ### Question 13
# Q13. To use the basic functions of pandas, what is the first and foremost necessary library that needs to
# be imported?
#
# pandas library itself is the most basic library to import to use pandas
# Below is how it is loaded
#
# import pandas as pd

# %% [markdown]
# ####  The End
